# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import numpy as np

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions (28,28)
img_rows, img_cols = 28, 28

# split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train data sample')
print(x_test.shape[0], 'test data samples')

# converting class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.30))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.55))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=2,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 81s 172ms/step - loss: 16.5404 - accuracy: 0.1645 - val_loss: 3.0010 - val_accuracy: 0.4391
# Epoch 2/12
# 469/469 [==============================] - 81s 173ms/step - loss: 8.0027 - accuracy: 0.2740 - val_loss: 1.4953 - val_accuracy: 0.5915
# Epoch 3/12
# 469/469 [==============================] - 81s 172ms/step - loss: 4.6176 - accuracy: 0.3483 - val_loss: 1.1255 - val_accuracy: 0.6325
# Epoch 4/12
# 469/469 [==============================] - 83s 176ms/step - loss: 3.0924 - accuracy: 0.3803 - val_loss: 1.1517 - val_accuracy: 0.6291
# Epoch 5/12
# 469/469 [==============================] - 81s 173ms/step - loss: 2.3818 - accuracy: 0.3938 - val_loss: 1.2461 - val_accuracy: 0.6289
# Epoch 6/12
# 469/469 [==============================] - 80s 171ms/step - loss: 2.0409 - accuracy: 0.4122 - val_loss: 1.2791 - val_accuracy: 0.6346
# Epoch 7/12
# 469/469 [==============================] - 80s 171ms/step - loss: 1.8809 - accuracy: 0.4244 - val_loss: 1.2497 - val_accuracy: 0.6515
# Epoch 8/12
# 469/469 [==============================] - 83s 176ms/step - loss: 1.7527 - accuracy: 0.4478 - val_loss: 1.1918 - val_accuracy: 0.6718
# Epoch 9/12
# 469/469 [==============================] - 80s 172ms/step - loss: 1.6687 - accuracy: 0.4692 - val_loss: 1.1194 - val_accuracy: 0.6946
# Epoch 10/12
# 469/469 [==============================] - 87s 186ms/step - loss: 1.5989 - accuracy: 0.4900 - val_loss: 1.0505 - val_accuracy: 0.7191
# Epoch 11/12
# 469/469 [==============================] - 80s 171ms/step - loss: 1.5229 - accuracy: 0.5149 - val_loss: 0.9803 - val_accuracy: 0.7388
# Epoch 12/12
# 469/469 [==============================] - 81s 172ms/step - loss: 1.4720 - accuracy: 0.5368 - val_loss: 0.9153 - val_accuracy: 0.7551
# Test loss: 0.9152863025665283
# Test accuracy: 0.7551000118255615

# %% [markdown]
# # The End
